# %% [markdown]
# ANALYSE THIS DATA ALSO IN POWERBI - LOAD IN THE CSV FILE. HOMEWORK

# %% [markdown]
# Read the file - I will work on top 10 datas.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('students/student_habits_performance.csv')

data.head(10)
data.groupby('gender').count()
# Out:
#         student_id  age  study_hours_per_day  social_media_hours  \
# gender
# Female         481  481                  481                 481
# Male           477  477                  477                 477
# Other           42   42                   42                  42
#
#         netflix_hours  part_time_job  attendance_percentage  sleep_hours  \
# gender
# Female            481            481                    481          481
# Male              477            477                    477          477
# Other              42             42                     42           42
#
#         diet_quality  exercise_frequency  parental_education_level  \
# gender
# Female           481                 481                       433
# Male             477                 477                       440
# Other             42                  42                        36
#
#         internet_quality  mental_health_rating  extracurricular_participation  \
# gender
# ...

# %% [markdown]
# Data tidy, rename some of the columns

# %%
data.rename(columns={'student_id':'ID','study_hours_per_day':'study_hours','social_media_hours':'sm_hours'})
# Out:
#         ID  age  gender  study_hours  sm_hours  netflix_hours part_time_job  \
# 0    S1000   23  Female          0.0       1.2            1.1            No
# 1    S1001   20  Female          6.9       2.8            2.3            No
# 2    S1002   21    Male          1.4       3.1            1.3            No
# 3    S1003   23  Female          1.0       3.9            1.0            No
# 4    S1004   19  Female          5.0       4.4            0.5            No
# ..     ...  ...     ...          ...       ...            ...           ...
# 995  S1995   21  Female          2.6       0.5            1.6            No
# 996  S1996   17  Female          2.9       1.0            2.4           Yes
# 997  S1997   20    Male          3.0       2.6            1.3            No
# 998  S1998   24    Male          5.4       4.1            1.1           Yes
# 999  S1999   19  Female          4.3       2.9            1.9            No
#
# ...

# %% [markdown]
# check for any duplicates

# %%
data.duplicated().head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %% [markdown]
# Select all of the males in the top 5 rows for .loc practice

# %%
data.loc[data['gender']=='Male'].head()
# Out:
#    student_id  age gender  study_hours_per_day  social_media_hours  \
# 2       S1002   21   Male                  1.4                 3.1
# 5       S1005   24   Male                  7.2                 1.3
# 11      S1011   23   Male                  3.9                 2.4
# 14      S1014   24   Male                  2.4                 1.5
# 15      S1015   21   Male                  3.1                 5.0
#
#     netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 2             1.3            No                   94.8          8.0
# 5             0.0            No                   82.9          7.4
# 11            2.5            No                   71.7          7.9
# 14            0.7            No                   87.4          6.7
# 15            1.0            No                   97.5          6.5
#
#    diet_quality  exercise_frequency parental_education_level internet_quality  \
# ...

# %% [markdown]
# Showcase analysis of how many males and females use social media hours - more females use it! Taken from whole dataset

# %%
grouped_sm = data.groupby('gender')['social_media_hours'].sum()

grouped_sm
# Out:
# gender
# Female    1204.4
# Male      1192.2
# Other      108.9
# Name: social_media_hours, dtype: float64

# %% [markdown]
# To make the results equal, I have made sure to select 'yes' for part time job for both males and females.

# %%
data_age_male = data.loc[(data['part_time_job']=='Yes') & (data['gender']== 'Male')].head(10)

data_age_male
# Out:
#     student_id  age gender  study_hours_per_day  social_media_hours  \
# 27       S1027   18   Male                  3.2                 2.2
# 28       S1028   24   Male                  4.3                 2.0
# 37       S1037   17   Male                  4.3                 2.5
# 62       S1062   21   Male                  4.5                 3.4
# 63       S1063   17   Male                  4.1                 2.3
# 79       S1079   20   Male                  5.9                 3.3
# 92       S1092   18   Male                  0.5                 0.8
# 105      S1105   18   Male                  1.4                 3.9
# 126      S1126   18   Male                  0.7                 3.4
# 150      S1150   19   Male                  3.5                 2.1
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 27             2.8           Yes                   88.1          4.8
# 28             2.8           Yes                   78.4          8.1
# ...

# %%
data_age_female = data.loc[(data['part_time_job']=='Yes') & (data['gender']== 'Female')].head(10)

data_age_female
# Out:
#    student_id  age  gender  study_hours_per_day  social_media_hours  \
# 6       S1006   21  Female                  5.6                 1.5
# 7       S1007   21  Female                  4.3                 1.0
# 12      S1012   19  Female                  3.7                 2.1
# 23      S1023   24  Female                  1.1                 4.1
# 24      S1024   20  Female                  2.0                 0.0
# 29      S1029   20  Female                  2.0                 3.2
# 35      S1035   21  Female                  4.2                 1.7
# 54      S1054   23  Female                  3.1                 1.9
# 60      S1060   19  Female                  1.7                 2.1
# 68      S1068   20  Female                  4.9                 0.3
#
#     netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 6             1.4           Yes                   85.8          6.5
# 7             2.0           Yes                   77.7          4.6
# ...

# %% [markdown]
# ?????????? ASK ERNEST :D     Now lets calculate the amount of study hours per gender per day for the first 10 results in the table. - MALE + Female

# %%
datam = data_age_male.head(100).groupby('gender')['study_hours_per_day'].sum()

dataf = data_age_female.head(100).groupby('gender')['study_hours_per_day'].sum()

datam = pd.DataFrame(datam)
dataf = pd.DataFrame(dataf)

datam
dataf

new_df = pd.concat([datam,dataf]) # it allows us to combine two dataframes together.

new_df
# Out:
#         study_hours_per_day
# gender
# Male                   32.4
# Female                 32.6

# %%
graph = new_df.plot(kind='pie',title='Hours Of Study Vs Gender',subplots=True,figsize=(8,8),autopct='%1.1f%%')


for ax in graph:
    ax.set_ylabel('')  # Removes the y-label (optional)
    ax.set_xlabel('')  # Removes the x-label (optional)
    ax.set_axis_off()  # Hides the axis completely

# %% [markdown]
# This showcases the amount of social media hours per age for the first 10 rows

# %%
grouped_data = data.head(10).groupby('age')['social_media_hours'].sum()
ax = grouped_data.head(10).plot(title='Social Media Hours Per Day',kind='bar',x='age',y='social_media_hours')
ax.set_xlabel('Age')
ax.set_ylabel('Hours')
# Out:
# Text(0, 0.5, 'Hours')

# %% [markdown]
# Student S1001 spends the most time on netlix although they spent the most time studying also

# %%
top_row = data.sort_values('netflix_hours', ascending=False).iloc[0]

top_row
# Out:
# student_id                          S1556
# age                                    24
# gender                             Female
# study_hours_per_day                   4.0
# social_media_hours                    3.3
# netflix_hours                         5.4
# part_time_job                          No
# attendance_percentage                81.2
# sleep_hours                           7.6
# diet_quality                         Fair
# exercise_frequency                      6
# parental_education_level         Bachelor
# internet_quality                     Poor
# mental_health_rating                    6
# extracurricular_participation          No
# exam_score                           79.0
# Name: 556, dtype: object

# %% [markdown]
# The below graph shows how many people work part time taking into consideration their study hours

# %%
grouped = data.groupby('part_time_job')['study_hours_per_day'].sum()


print(grouped)


ax = grouped.head(10).plot(title='Job to study ratio',kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# part_time_job
# No     2804.4
# Yes     745.7
# Name: study_hours_per_day, dtype: float64
# Text(0, 0.5, '')

# %% [markdown]
# Do sleep hours reflect the students attendance?
#
# for quick info data.sample(45) creates random samples

# %%
ax = data.head(1000).plot(title='Hours of sleep vs Attendance', kind='scatter',x='sleep_hours',y='attendance_percentage')
ax.set_xlabel('sleep hours')
ax.set_ylabel('attendance percentage')
# Out:
# Text(0, 0.5, 'attendance percentage')

# %% [markdown]
# Does attendance percentage have an impact on the exam score?

# %%
ax = data.head(1000).plot(title='Attendance vs Exam Scores',kind='scatter',x='attendance_percentage', y='exam_score')

# %% [markdown]
# # **NOW LETS MOVE ON TO SAMPLE DATA**
#
# From the below results we can gather that Male students study harder for the exams.

# %%
samples = data.sample(1000)

samples.groupby('gender')['exam_score'].agg(['min','mean','max'])
# Out:
#          min       mean    max
# gender
# Female  18.4  69.741372  100.0
# Male    23.1  69.368344  100.0
# Other   43.9  70.647619  100.0

# %% [markdown]
# Show on the graph the sum of exam score by gender out of a random sample

# %%
random_graph = data.sample(1000)

ax = random_graph.groupby('gender')['exam_score'].sum().plot(title='Exam scores vs Gender',kind='barh',x='gender',y='exam_score')

ax.set_xlabel('exam score')
ax.set_ylabel('gender')

ax
# Out:
# <Axes: title={'center': 'Exam scores vs Gender'}, xlabel='exam score', ylabel='gender'>

# %% [markdown]
# Lets use .loc and sample data to present everyone that is below the age of 20 and has a good diet

# %%
sample_data = data.loc[(data['diet_quality']=='Good') & (data['age'] <= 20)].sample(100)

sample_data
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 37       S1037   17    Male                  4.3                 2.5
# 933      S1933   17  Female                  1.8                 3.0
# 863      S1863   18  Female                  1.5                 3.9
# 458      S1458   19    Male                  2.9                 3.0
# 323      S1323   18    Male                  2.9                 1.6
# ..         ...  ...     ...                  ...                 ...
# 594      S1594   20    Male                  4.3                 2.4
# 731      S1731   17    Male                  3.5                 0.0
# 853      S1853   19  Female                  2.1                 0.8
# 333      S1333   19    Male                  3.8                 4.2
# 317      S1317   17    Male                  4.1                 4.2
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %% [markdown]
# Women have better a diet

# %%
ax = sample_data.groupby('gender')['age'].sum().plot(title='Gender vs Age', kind='bar',x='gender',y='age')
